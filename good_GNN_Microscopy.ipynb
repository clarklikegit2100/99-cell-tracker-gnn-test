# %% [markdown]
# # **This Notebook is provided Training Example (PhC-C2DH-U373 Dataset) Using Colab**
# The notebook arragemnet is as follow
#
# *   **Prequesities**
#   1.   Conect to github, Clone the repository
#   2.   Configurate working directory and google drive connetction
#   3.   Download and install Conda, create conda enviroment with all the required packages
#
# *   **Trainings**
#   1.   Run feature extraction for metric learning
#   2.   Run metric learning training
#   3.   Run compreensive feature extraction with metric learning
#   4.   Run Cell Tracking training
#
# *   **Inference**

# %% [markdown]
# # **Prequesities**

# %% [markdown]
# # 1. Conect to github, Clone the repository

# %%
import os
#! git clone https://github.com/talbenha/cell-tracker-gnn

#curr_workdir = f'./cell-tracker-gnn'
#if os.path.exists(curr_workdir):
#  os.chdir(curr_workdir)
# Out:
# Cloning into 'cell-tracker-gnn'...
# remote: Enumerating objects: 504, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 504 (delta 179), reused 191 (delta 156), pack-reused 277 (from 1)
# Receiving objects: 100% (504/504), 38.01 MiB | 14.00 MiB/s, done.
# Resolving deltas: 100% (261/261), done.

# %% [markdown]
# # 2. Configurate working directory and google drive connetction

# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
file_path = '/content/drive/My Drive/CellTracking/nature_method_ctc/' # TODO: update this path
if os.path.exists(file_path):
  os.listdir(file_path)
else:
  print("Error Path doesn't exist")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 3. Download and install Conda, create conda enviroment with all the required packages

# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################

# try to run the bare minimum to get a new conda env working
env_name = 'cell-tracking-challenge'
conda_path = ''
try:
    conda_path = ! which conda
finally:
    print('')

if (len(conda_path) == 0):
    print('installing miniconda')
    ! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
    ! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
    ! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
    import sys
    sys.path.append('/usr/local/lib/python3.7/site-packages/')
    ! conda init
    ! conda install -n root _license -y -q
else:
    print('found miniconda')

conda_envs = ! conda env list
res = [i for i in conda_envs if env_name in i]
if (len(res) == 0):
    print(f'not found {env_name} env', len(res))
    ! conda create --name cell-tracking-challenge-mac310 --file requirements-conda.txt
else:
    print(f'found {env_name} env', len(res))
print(f'{env_name} was created')
# Out:
# installing miniconda
# --2025-06-23 14:07:13--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   275MB/s    in 0.3s
#
# 2025-06-23 14:07:14 (275 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_1
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==45.2.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   asn1crypto         pkgs/main/linux-64::asn1crypto-1.3.0-py37_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.1.1-0
#   certifi            pkgs/main/linux-64::certifi-2019.11.28-py37_0
#   cffi               pkgs/main/linux-64::cffi-1.14.0-py37h2e261b9_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py37_1003
#   conda              pkgs/main/linux-64::conda-4.8.2-py37_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.6.0-py37h7b6447c_0
#   cryptography       pkgs/main/linux-64::cryptography-2.8-py37h1ba5d50_0
#   idna               pkgs/main/linux-64::idna-2.8-py37_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20181209-hc058e9b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hd88cf55_4
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1d-h7b6447c_4
#   pip                pkgs/main/linux-64::pip-20.0.2-py37_1
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py37h7b6447c_0
#   pycparser          pkgs/main/linux-64::pycparser-2.19-py37_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-py37_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py37_0
#   python             pkgs/main/linux-64::python-3.7.6-h0371630_2
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   requests           pkgs/main/linux-64::requests-2.22.0-py37_1
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py37h7b6447c_0
#   setuptools         pkgs/main/linux-64::setuptools-45.2.0-py37_0
#   six                pkgs/main/linux-64::six-1.14.0-py37_0
#   sqlite             pkgs/main/linux-64::sqlite-3.31.1-h7b6447c_0
#   tk                 pkgs/main/linux-64::tk-8.6.8-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.42.1-py_0
#   urllib3            pkgs/main/linux-64::urllib3-1.25.8-py37_0
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py37_0
#   xz                 pkgs/main/linux-64::xz-5.2.4-h14c3975_4
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.7/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - _license
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# not found cell-tracking-challenge env 0
#
# Downloading and Extracting Packages
# _libgcc_mutex-0.1    | : 100% 1.0/1 [00:00<00:00,  7.58it/s]
# _tflow_select-2.1.0  | : 100% 1.0/1 [00:00<00:00,  8.71it/s]
# ca-certificates-2022 | : 100% 1.0/1 [00:00<00:00, 18.57it/s]
# ld_impl_linux-64-2.3 | : 100% 1.0/1 [00:00<00:00,  5.98it/s]
# libgfortran4-7.5.0   | : 100% 1.0/1 [00:00<00:00,  3.74it/s]
# libstdcxx-ng-11.2.0  | : 100% 1.0/1 [00:02<00:00,  2.18s/it]
# llvm-openmp-12.0.1   | : 100% 1.0/1 [00:00<00:00,  2.27it/s]
# mysql-common-8.0.25  | : 100% 1.0/1 [00:00<00:00,  2.58it/s]
# _openmp_mutex-4.5    | : 100% 1.0/1 [00:00<00:00, 28.36it/s]
# libgfortran-ng-7.5.0 | : 100% 1.0/1 [00:00<00:00, 28.79it/s]
# libgcc-ng-12.1.0     | : 100% 1.0/1 [00:00<00:00,  6.19it/s]
# mkl-2020.4           | : 100% 1.0/1 [00:38<00:00, 38.29s/it]
# abseil-cpp-20210324. | : 100% 1.0/1 [00:00<00:00, 10.12s/it]
# brotli-1.0.9         | : 100% 1.0/1 [00:00<00:00, 11.11it/s]
# bzip2-1.0.8          | : 100% 1.0/1 [00:00<00:00, 13.86it/s]
# c-ares-1.18.1        | : 100% 1.0/1 [00:00<00:00, 16.20it/s]
# charls-2.2.0         | : 100% 1.0/1 [00:00<00:00, 16.63it/s]
# cudatoolkit-11.1.1   | : 100% 1.0/1 [02:49<00:00, 169.09s/it]
# expat-2.4.4          | : 100% 1.0/1 [00:00<00:00,  8.20it/s]
# giflib-5.2.1         | : 100% 1.0/1 [00:00<00:00, 13.32it/s]
# gmp-6.2.1            | : 100% 1.0/1 [00:00<00:00,  5.87it/s]
# graphite2-1.3.14     | : 100% 1.0/1 [00:00<00:00, 23.57it/s]
# icu-68.1             | : 100% 1.0/1 [00:03<00:00,  4.62s/it]
# jpeg-9e              | : 100% 1.0/1 [00:00<00:00, 10.90it/s]
# jxrlib-1.1           | : 100% 1.0/1 [00:00<00:00, 14.49it/s]
# lame-3.100           | : 100% 1.0/1 [00:00<00:00,  8.60it/s]
# lerc-3.0             | : 100% 1.0/1 [00:00<00:00, 13.85it/s]
# libaec-1.0.4         | : 100% 1.0/1 [00:00<00:00,  3.10it/s]
# libblas-3.9.0        | : 100% 1.0/1 [00:00<00:00, 22.72it/s]
# libdeflate-1.8       | : 100% 1.0/1 [00:00<00:00,  3.13it/s]
# libev-4.33           | : 100% 1.0/1 [00:00<00:00, 15.57it/s]
# libffi-3.3           | : 100% 1.0/1 [00:00<00:00,  7.17it/s]
# libiconv-1.16        | : 100% 1.0/1 [00:00<00:00,  5.06it/s]
# libtasn1-4.16.0      | : 100% 1.0/1 [00:00<00:00, 18.44it/s]
# libunistring-0.9.10  | : 100% 1.0/1 [00:00<00:00,  6.36it/s]
# libuuid-1.0.3        | : 100% 1.0/1 [00:00<00:00, 19.04it/s]
# libwebp-base-1.2.2   | : 100% 1.0/1 [00:00<00:00,  4.79it/s]
# libxcb-1.14          | : 100% 1.0/1 [00:00<00:00, 12.72s/it]
# libzopfli-1.0.3      | : 100% 1.0/1 [00:00<00:00, 13.06it/s]
# lz4-c-1.9.3          | : 100% 1.0/1 [00:00<00:00, 11.29it/s]
# ncurses-6.3          | : 100% 1.0/1 [00:00<00:00,  2.58it/s]
# ninja-base-1.10.2    | : 100% 1.0/1 [00:00<00:00, 19.52it/s]
# nspr-4.33            | : 100% 1.0/1 [00:00<00:00,  9.85it/s]
# openh264-2.1.1       | : 100% 1.0/1 [00:00<00:00,  3.08it/s]
# openssl-1.1.1n       | : 100% 1.0/1 [00:00<00:00,  1.31it/s]
# pcre-8.45            | : 100% 1.0/1 [00:00<00:00, 12.88it/s]
# pixman-0.40.0        | : 100% 1.0/1 [00:00<00:00,  6.63it/s]
# re2-2021.08.01       | : 100% 1.0/1 [00:00<00:00, 13.41it/s]
# sleef-3.5.1          | : 100% 1.0/1 [00:00<00:00,  3.04it/s]
# snappy-1.1.9         | : 100% 1.0/1 [00:00<00:00,  5.55it/s]
# x264-1!152.20180806  | : 100% 1.0/1 [00:01<00:00,  7.31s/it]
# xz-5.2.5             | : 100% 1.0/1 [00:00<00:00,  6.94it/s]
# yaml-0.2.5           | : 100% 1.0/1 [00:00<00:00, 22.54it/s]
# zfp-0.5.5            | : 100% 1.0/1 [00:00<00:00,  6.48it/s]
# zlib-1.2.12          | : 100% 1.0/1 [00:00<00:00,  7.79it/s]
# blosc-1.21.1         | : 100% 1.0/1 [00:00<00:00,  5.81it/s]
# brunsli-0.1          | : 100% 1.0/1 [00:00<00:00, 14.00it/s]
# glib-2.68.2          | : 100% 1.0/1 [00:00<00:00,  1.43it/s]
# hdf5-1.10.6          | : 100% 1.0/1 [00:00<00:00,  1.27it/s]
# jasper-1.900.1       | : 100% 1.0/1 [00:00<00:00, 11.15it/s]
# libcblas-3.9.0       | : 100% 1.0/1 [00:00<00:00, 24.23it/s]
# libedit-3.1.20210910 | : 100% 1.0/1 [00:00<00:00, 11.93it/s]
# libevent-2.1.10      | : 100% 1.0/1 [00:00<00:00,  3.72it/s]
# libidn2-2.3.2        | : 100% 1.0/1 [00:00<00:00, 21.31it/s]
# liblapack-3.9.0      | : 100% 1.0/1 [00:00<00:00, 19.81it/s]
# libllvm11-11.1.0     | : 100% 1.0/1 [00:04<00:00,  2.60s/it]
# libnghttp2-1.46.0    | : 100% 1.0/1 [00:00<00:00, 16.39s/it]
# libpng-1.6.37        | : 100% 1.0/1 [00:00<00:00, 11.19it/s]
# libprotobuf-3.15.8   | : 100% 1.0/1 [00:00<00:00,  1.75it/s]
# libssh2-1.10.0       | : 100% 1.0/1 [00:00<00:00,  8.55it/s]
# libxml2-2.9.12       | : 100% 1.0/1 [00:00<00:00,  5.33it/s]
# nettle-3.7.3         | : 100% 1.0/1 [00:00<00:00,  4.52it/s]
# readline-8.1.2       | : 100% 1.0/1 [00:00<00:00,  4.50it/s]
# tk-8.6.11            | : 100% 1.0/1 [00:01<00:00,  4.62s/it]
# zstd-1.4.9           | : 100% 1.0/1 [00:00<00:00,  6.90it/s]
# dbus-1.13.18         | : 100% 1.0/1 [00:00<00:00,  7.72it/s]
# freetype-2.11.0      | : 100% 1.0/1 [00:00<00:00,  4.82it/s]
# gettext-0.21.0       | : 100% 1.0/1 [00:00<00:00,  1.54it/s]
# gnutls-3.6.15        | : 100% 1.0/1 [00:00<00:00,  4.72it/s]
# grpc-cpp-1.37.1      | : 100% 1.0/1 [00:00<00:00,  1.67it/s]
# krb5-1.19.2          | : 100% 1.0/1 [00:00<00:00,  3.99it/s]
# libclang-11.1.0      | : 100% 1.0/1 [00:03<00:00,  2.33s/it]
# libfaiss-1.7.2       | : 100% 1.0/1 [00:13<00:00, 13.98s/it]
# libfaiss-avx2-1.7.2  | : 100% 1.0/1 [00:16<00:00, 35.14s/it]
# liblapacke-3.9.0     | : 100% 1.0/1 [00:00<00:00, 18.85it/s]
# libtiff-4.2.0        | : 100% 1.0/1 [00:00<00:00,  7.62it/s]
# libxkbcommon-1.0.3   | : 100% 1.0/1 [00:00<00:00,  6.98it/s]
# mysql-libs-8.0.25    | : 100% 1.0/1 [00:00<00:00,  2.88it/s]
# sqlite-3.38.3        | : 100% 1.0/1 [00:00<00:00,  5.47it/s]
# ffmpeg-4.3.1         | : 100% 1.0/1 [00:12<00:00, 87.99s/it]
# fontconfig-2.13.1    | : 100% 1.0/1 [00:00<00:00,  7.46it/s]
# lcms2-2.12           | : 100% 1.0/1 [00:00<00:00,  8.48it/s]
# libcurl-7.82.0       | : 100% 1.0/1 [00:00<00:00,  9.38it/s]
# libglib-2.68.2       | : 100% 1.0/1 [00:00<00:00,  1.43it/s]
# libpq-12.9           | : 100% 1.0/1 [00:00<00:00,  1.73it/s]
# libwebp-1.2.2        | : 100% 1.0/1 [00:00<00:00, 12.60it/s]
# nss-3.74             | : 100% 1.0/1 [00:00<00:00,  2.08it/s]
# openjpeg-2.4.0       | : 100% 1.0/1 [00:00<00:00,  6.86it/s]
# python-3.8.13        | : 100% 1.0/1 [00:00<00:00,  1.70it/s]
# appdirs-1.4.4        | : 100% 1.0/1 [00:00<00:00, 27.00it/s]
# attrs-21.4.0         | : 100% 1.0/1 [00:00<00:00, 22.12it/s]
# blinker-1.4          | : 100% 1.0/1 [00:00<00:00, 18.89it/s]
# cachetools-4.2.2     | : 100% 1.0/1 [00:00<00:00, 24.34it/s]
# cairo-1.16.0         | : 100% 1.0/1 [00:01<00:00, 12.09s/it]
# certifi-2021.10.8    | : 100% 1.0/1 [00:00<00:00, 15.70it/s]
# cfgv-3.3.1           | : 100% 1.0/1 [00:00<00:00, 29.44it/s]
# cfitsio-3.470        | : 100% 1.0/1 [00:00<00:00,  3.86it/s]
# charset-normalizer-2 | : 100% 1.0/1 [00:00<00:00, 23.17it/s]
# click-8.0.4          | : 100% 1.0/1 [00:00<00:00,  2.28it/s]
# cloudpickle-2.0.0    | : 100% 1.0/1 [00:00<00:00, 27.56it/s]
# colorama-0.4.4       | : 100% 1.0/1 [00:00<00:00, 28.97it/s]
# cycler-0.11.0        | : 100% 1.0/1 [00:00<00:00, 27.20it/s]
# dataclasses-0.8      | : 100% 1.0/1 [00:00<00:00, 33.61it/s]
# distlib-0.3.2        | : 100% 1.0/1 [00:00<00:00,  1.94it/s]
# filelock-3.6.0       | : 100% 1.0/1 [00:00<00:00,  2.11it/s]
# frozenlist-1.2.0     | : 100% 1.0/1 [00:00<00:00,  2.84it/s]
# fsspec-2022.2.0      | : 100% 1.0/1 [00:00<00:00, 20.49it/s]
# future-0.18.2        | : 100% 1.0/1 [00:00<00:00,  6.91s/it]
# gast-0.3.3           | : 100% 1.0/1 [00:00<00:00, 29.68it/s]
# gstreamer-1.18.4     | : 100% 1.0/1 [00:00<00:00,  2.40it/s]
# idna-3.3             | : 100% 1.0/1 [00:00<00:00, 21.37it/s]
# iniconfig-1.1.1      | : 100% 1.0/1 [00:00<00:00, 26.14it/s]
# joblib-1.1.0         | : 100% 1.0/1 [00:00<00:00, 11.79it/s]
# kiwisolver-1.3.2     | : 100% 1.0/1 [00:00<00:00,  3.35it/s]
# locket-0.2.1         | : 100% 1.0/1 [00:00<00:00,  2.97it/s]
# markupsafe-2.0.1     | : 100% 1.0/1 [00:00<00:00,  3.26it/s]
# multidict-5.2.0      | : 100% 1.0/1 [00:00<00:00,  2.34it/s]
# munkres-1.1.4        | : 100% 1.0/1 [00:00<00:00, 29.48it/s]
# networkx-2.7.1       | : 100% 1.0/1 [00:00<00:00,  3.03it/s]
# ninja-1.10.2         | : 100% 1.0/1 [00:00<00:00, 29.99it/s]
# parso-0.8.3          | : 100% 1.0/1 [00:00<00:00, 15.36it/s]
# pillow-9.0.1         | : 100% 1.0/1 [00:00<00:00, 13.26s/it]
# pluggy-1.0.0         | : 100% 1.0/1 [00:00<00:00, 25.34it/s]
# py-1.11.0            | : 100% 1.0/1 [00:00<00:00, 16.77it/s]
# pyasn1-0.4.8         | : 100% 1.0/1 [00:00<00:00, 21.53it/s]
# pycparser-2.21       | : 100% 1.0/1 [00:00<00:00, 17.45it/s]
# pydeprecate-0.3.1    | : 100% 1.0/1 [00:00<00:00, 23.06it/s]
# pygments-2.11.2      | : 100% 1.0/1 [00:00<00:00,  5.29it/s]
# pyparsing-3.0.4      | : 100% 1.0/1 [00:00<00:00, 19.88it/s]
# pysocks-1.7.1        | : 100% 1.0/1 [00:00<00:00, 25.58it/s]
# python-flatbuffers-1 | : 100% 1.0/1 [00:00<00:00, 27.01it/s]
# python_abi-3.8       | : 100% 1.0/1 [00:00<00:00, 19.23it/s]
# pytz-2021.3          | : 100% 1.0/1 [00:00<00:00,  9.07it/s]
# pyyaml-6.0           | : 100% 1.0/1 [00:00<00:00, 15.91it/s]
# six-1.16.0           | : 100% 1.0/1 [00:00<00:00, 25.35it/s]
# termcolor-1.1.0      | : 100% 1.0/1 [00:00<00:00,  3.38it/s]
# threadpoolctl-2.2.0  | : 100% 1.0/1 [00:00<00:00, 25.56it/s]
# toml-0.10.2          | : 100% 1.0/1 [00:00<00:00, 23.95it/s]
# tomli-1.2.2          | : 100% 1.0/1 [00:00<00:00,  2.65it/s]
# toolz-0.11.2         | : 100% 1.0/1 [00:00<00:00, 15.60it/s]
# tornado-6.1          | : 100% 1.0/1 [00:00<00:00,  4.57it/s]
# tqdm-4.64.0          | : 100% 1.0/1 [00:00<00:00,  2.37s/it]
# typing_extensions-4. | : 100% 1.0/1 [00:00<00:00, 17.19it/s]
# urwid-2.1.2          | : 100% 1.0/1 [00:00<00:00,  6.54it/s]
# wheel-0.37.1         | : 100% 1.0/1 [00:00<00:00,  7.02it/s]
# wrapt-1.13.3         | : 100% 1.0/1 [00:00<00:00,  2.55it/s]
# zipp-3.7.0           | : 100% 1.0/1 [00:00<00:00, 26.09it/s]
# absl-py-0.15.0       | : 100% 1.0/1 [00:00<00:00, 15.89it/s]
# aiosignal-1.2.0      | : 100% 1.0/1 [00:00<00:00, 25.45it/s]
# astunparse-1.6.3     | : 100% 1.0/1 [00:00<00:00, 23.22it/s]
# cffi-1.15.0          | : 100% 1.0/1 [00:00<00:00, 10.83it/s]
# commonmark-0.9.1     | : 100% 1.0/1 [00:00<00:00, 16.17it/s]
# cytoolz-0.11.0       | : 100% 1.0/1 [00:00<00:00,  7.72it/s]
# fonttools-4.25.0     | : 100% 1.0/1 [00:00<00:00,  4.58it/s]
# google-pasta-0.2.0   | : 100% 1.0/1 [00:00<00:00, 17.67it/s]
# gst-plugins-base-1.1 | : 100% 1.0/1 [00:01<00:00,  1.03s/it]
# harfbuzz-2.8.1       | : 100% 1.0/1 [00:00<00:00,  2.97it/s]
# importlib-metadata-4 | : 100% 1.0/1 [00:00<00:00,  2.72it/s]
# jedi-0.18.1          | : 100% 1.0/1 [00:00<00:00,  2.50it/s]
# jinja2-3.0.3         | : 100% 1.0/1 [00:00<00:00, 19.72it/s]
# numpy-1.22.3         | : 100% 1.0/1 [00:01<00:00,  1.27it/s]
# packaging-21.3       | : 100% 1.0/1 [00:00<00:00, 22.15it/s]
# partd-1.2.0          | : 100% 1.0/1 [00:00<00:00, 25.35it/s]
# pyasn1-modules-0.2.8 | : 100% 1.0/1 [00:00<00:00, 17.27it/s]
# python-dateutil-2.8. | : 100% 1.0/1 [00:00<00:00, 15.40it/s]
# python-dotenv-0.20.0 | : 100% 1.0/1 [00:00<00:00, 21.65it/s]
# rsa-4.7.2            | : 100% 1.0/1 [00:00<00:00, 27.75it/s]
# setuptools-61.2.0    | : 100% 1.0/1 [00:01<00:00,  4.09s/it]
# typing-extensions-4. | : 100% 1.0/1 [00:00<00:00, 26.72it/s]
# urwid_readline-0.13  | : 100% 1.0/1 [00:00<00:00,  2.12it/s]
# virtualenv-20.4.6    | : 100% 1.0/1 [00:01<00:00,  1.41s/it]
# werkzeug-2.0.3       | : 100% 1.0/1 [00:00<00:00, 11.65it/s]
# yacs-0.1.6           | : 100% 1.0/1 [00:00<00:00,  6.67it/s]
# yarl-1.6.3           | : 100% 1.0/1 [00:00<00:00,  1.48it/s]
# async-timeout-4.0.1  | : 100% 1.0/1 [00:00<00:00, 27.53it/s]
# bottleneck-1.3.4     | : 100% 1.0/1 [00:00<00:00, 18.08it/s]
# brotlipy-0.7.0       | : 100% 1.0/1 [00:00<00:00, 12.09it/s]
# cryptography-36.0.0  | : 100% 1.0/1 [00:00<00:00,  1.23it/s]
# dask-core-2022.2.1   | : 100% 1.0/1 [00:00<00:00, 18.35s/it]
# faiss-1.7.2          | : 100% 1.0/1 [00:01<00:00, 24.04s/it]
# grpcio-1.37.1        | : 100% 1.0/1 [00:00<00:00,  2.00it/s]
# h5py-2.10.0          | : 100% 1.0/1 [00:00<00:00,  3.60it/s]
# imagecodecs-2021.8.2 | : 100% 1.0/1 [00:02<00:00, 142.41s/it]
# imageio-2.9.0        | : 100% 1.0/1 [00:00<00:00,  2.58it/s]
# markdown-3.3.4       | : 100% 1.0/1 [00:00<00:00,  2.02it/s]
# matplotlib-base-3.5. | : 100% 1.0/1 [00:01<00:00,  1.21s/it]
# nodeenv-1.6.0        | : 100% 1.0/1 [00:00<00:00,  3.29it/s]
# numexpr-2.7.3        | : 100% 1.0/1 [00:00<00:00, 14.57it/s]
# opt_einsum-3.3.0     | : 100% 1.0/1 [00:00<00:00, 22.22it/s]
# pip-21.2.4           | : 100% 1.0/1 [00:01<00:00,  3.85s/it]
# protobuf-3.15.8      | : 100% 1.0/1 [00:00<00:00,  9.04it/s]
# pudb-2022.1          | : 100% 1.0/1 [00:00<00:00,  2.96it/s]
# pytest-7.1.1         | : 100% 1.0/1 [00:00<00:00, 10.50s/it]
# python-louvain-0.15  | : 100% 1.0/1 [00:00<00:00,  2.32it/s]
# pytorch-1.8.0        | : 100% 1.0/1 [03:24<00:00, 204.31s/it]
# pywavelets-1.3.0     | : 100% 1.0/1 [00:01<00:00, 14.73s/it]
# qt-5.12.9            | : 100% 1.0/1 [00:16<00:00, 16.80s/it]
# rich-10.16.2         | : 100% 1.0/1 [00:00<00:00,  1.53it/s]
# scipy-1.5.3          | : 100% 1.0/1 [00:02<00:00,  2.25s/it]
# tensorboard-plugin-w | : 100% 1.0/1 [00:00<00:00,  4.67s/it]
# torchvision-0.9.0    | : 100% 1.0/1 [00:00<00:00,  1.30it/s]
# ukkonen-1.0.1        | : 100% 1.0/1 [00:00<00:00, 11.41it/s]
# aiohttp-3.8.1        | : 100% 1.0/1 [00:01<00:00,  3.42s/it]
# faiss-gpu-1.7.2      | : 100% 1.0/1 [00:00<00:00,  3.41it/s]
# identify-2.5.1       | : 100% 1.0/1 [00:00<00:00,  2.53it/s]
# keras-preprocessing- | : 100% 1.0/1 [00:00<00:00, 11.55it/s]
# libopencv-4.5.2      | : 100% 1.0/1 [00:05<00:00,  5.72s/it]
# pandas-1.4.2         | : 100% 1.0/1 [00:02<00:00,  1.61s/it]
# pyjwt-1.7.1          | : 100% 1.0/1 [00:00<00:00,  1.74it/s]
# pyopenssl-22.0.0     | : 100% 1.0/1 [00:00<00:00, 25.20it/s]
# pyqt-5.12.3          | : 100% 1.0/1 [00:01<00:00, 61.58s/it]
# pytorch-cluster-1.5. | : 100% 1.0/1 [00:03<00:00,  3.28s/it]
# pytorch-scatter-2.0. | : 100% 1.0/1 [00:05<00:00,  5.55s/it]
# pytorch-spline-conv- | : 100% 1.0/1 [00:03<00:00,  3.22s/it]
# scikit-learn-1.0.2   | : 100% 1.0/1 [00:01<00:00,  1.04it/s]
# tifffile-2021.7.2    | : 100% 1.0/1 [00:00<00:00,  8.69it/s]
# torchmetrics-0.6.0   | : 100% 1.0/1 [00:00<00:00, 13.53it/s]
# matplotlib-3.5.1     | : 100% 1.0/1 [00:00<00:00,  2.42it/s]
# oauthlib-3.1.0       | : 100% 1.0/1 [00:00<00:00, 11.49it/s]
# pre-commit-2.19.0    | : 100% 1.0/1 [00:00<00:00,  1.23it/s]
# py-opencv-4.5.2      | : 100% 1.0/1 [00:00<00:00,  5.17s/it]
# pytorch-metric-learn | : 100% 1.0/1 [00:01<00:00,  1.83s/it]
# pytorch-sparse-0.6.1 | : 100% 1.0/1 [00:10<00:00, 10.44s/it]
# scikit-image-0.19.2  | : 100% 1.0/1 [00:01<00:00,  2.04s/it]
# urllib3-1.26.9       | : 100% 1.0/1 [00:00<00:00,  2.07it/s]
# opencv-4.5.2         | : 100% 1.0/1 [00:00<00:00,  1.89it/s]
# pre_commit-2.19.0    | : 100% 1.0/1 [00:00<00:00,  2.21it/s]
# requests-2.27.1      | : 100% 1.0/1 [00:00<00:00, 21.74it/s]
# seaborn-0.11.2       | : 100% 1.0/1 [00:00<00:00, 12.29it/s]
# google-auth-2.6.0    | : 100% 1.0/1 [00:00<00:00, 17.99it/s]
# googledrivedownloade | : 100% 1.0/1 [00:00<00:00, 26.32it/s]
# requests-oauthlib-1. | : 100% 1.0/1 [00:00<00:00, 27.81it/s]
# google-auth-oauthlib | : 100% 1.0/1 [00:00<00:00, 25.41it/s]
# pyg-2.0.1            | : 100% 1.0/1 [00:03<00:00,  3.04s/it]
# tensorboard-2.4.0    | : 100% 1.0/1 [00:02<00:00,  2.36s/it]
# pytorch-lightning-1. | : 100% 1.0/1 [00:00<00:00,  8.53it/s]
# tensorflow-gpu-2.4.1 | : 100% 1.0/1 [00:00<00:00, 26.63it/s]
# tensorflow-estimator | : 100% 1.0/1 [00:00<00:00,  6.72s/it]
# tensorflow-base-2.4. | : 100% 1.0/1 [00:19<00:00, 19.23s/it]
# tensorflow-2.4.1     | : 100% 1.0/1 [00:00<00:00, 10.66it/s]
# done
# done
# \ b'By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html\n'
# / b'\n\n    Installed package of scikit-learn can be accelerated using scikit-learn-intelex.\n    More details are available here: https://intel.github.io/scikit-learn-intelex\n\n    For example:\n\n        $ conda install scikit-learn-intelex\n        $ python -m sklearnex my_application.py\n\n    \n'
# done
# cell-tracking-challenge was created

# %%
# %%bash
# source activate cell-tracking-challenge
# # install other requirements
# pip install -r requirements.txt
# pip install PyYAML==5.4.1
# Out:
# Collecting hydra-core==1.1.0.dev5
#   Downloading hydra_core-1.1.0.dev5-py3-none-any.whl (136 kB)
# Collecting hydra-colorlog==1.0.0
#   Downloading hydra_colorlog-1.0.0-py3-none-any.whl (3.6 kB)
# Collecting hydra-optuna-sweeper==0.9.0rc2
#   Downloading hydra_optuna_sweeper-0.9.0rc2-py3-none-any.whl (5.9 kB)
# Collecting wandb>=0.10.20
#   Downloading wandb-0.18.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
# Collecting importlib-resources; python_version < "3.9"
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting antlr4-python3-runtime==4.8
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
# Collecting omegaconf==2.1.0dev24
#   Downloading omegaconf-2.1.0.dev24-py3-none-any.whl (66 kB)
# Collecting colorlog
#   Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from wandb>=0.10.20->-r requirements.txt (line 8)) (45.2.0.post20200210)
# Collecting psutil>=5.0.0
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# Collecting pyyaml
#   Downloading PyYAML-6.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (670 kB)
# Collecting click!=8.0.0,>=7.1
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/site-packages (from wandb>=0.10.20->-r requirements.txt (line 8)) (2.22.0)
# Collecting sentry-sdk>=2.0.0
#   Downloading sentry_sdk-2.30.0-py2.py3-none-any.whl (343 kB)
# Collecting protobuf!=4.21.0,!=5.28.0,<6,>=3.12.0; python_version < "3.9" and sys_platform == "linux"
#   Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
# Collecting gitpython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Collecting typing-extensions<5,>=4.4; python_version < "3.12"
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting platformdirs
#   Downloading platformdirs-4.0.0-py3-none-any.whl (17 kB)
# Collecting zipp>=3.1.0; python_version < "3.10"
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.12.1-py3-none-any.whl (226 kB)
# Collecting numpy
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Collecting packaging>=20.0
#   Downloading packaging-24.0-py3-none-any.whl (53 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/site-packages (from optuna->hydra-optuna-sweeper==0.9.0rc2->-r requirements.txt (line 6)) (4.42.1)
# Collecting sqlalchemy>=1.3.0
#   Downloading SQLAlchemy-2.0.41-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.7/site-packages (from docker-pycreds>=0.4.0->wandb>=0.10.20->-r requirements.txt (line 8)) (1.14.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests<3,>=2.0.0->wandb>=0.10.20->-r requirements.txt (line 8)) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests<3,>=2.0.0->wandb>=0.10.20->-r requirements.txt (line 8)) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests<3,>=2.0.0->wandb>=0.10.20->-r requirements.txt (line 8)) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests<3,>=2.0.0->wandb>=0.10.20->-r requirements.txt (line 8)) (1.25.8)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
# Collecting greenlet>=1; python_version < "3.14" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32"))))))
#   Downloading greenlet-3.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (602 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Collecting MarkupSafe>=0.9.2
#   Downloading MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141230 sha256=8aaf448971d69fa2ef164f05c50bba0fe2626a51e0e86c6e738156e3532d807b
#   Stored in directory: /root/.cache/pip/wheels/ca/33/b7/336836125fc9bb4ceaa4376d8abca10ca8bc84ddc824baea6c
# Successfully built antlr4-python3-runtime
# Installing collected packages: zipp, importlib-resources, antlr4-python3-runtime, pyyaml, omegaconf, hydra-core, colorlog, hydra-colorlog, typing-extensions, MarkupSafe, importlib-metadata, Mako, greenlet, sqlalchemy, alembic, numpy, packaging, optuna, hydra-optuna-sweeper, psutil, click, setproctitle, docker-pycreds, sentry-sdk, protobuf, smmap, gitdb, gitpython, platformdirs, wandb
# Successfully installed Mako-1.2.4 MarkupSafe-2.1.5 alembic-1.12.1 antlr4-python3-runtime-4.8 click-8.1.8 colorlog-6.9.0 docker-pycreds-0.4.0 gitdb-4.0.12 gitpython-3.1.44 greenlet-3.1.1 hydra-colorlog-1.0.0 hydra-core-1.1.0.dev5 hydra-optuna-sweeper-0.9.0rc2 importlib-metadata-6.7.0 importlib-resources-5.12.0 numpy-1.21.6 omegaconf-2.1.0.dev24 optuna-4.0.0 packaging-24.0 platformdirs-4.0.0 protobuf-4.24.4 psutil-7.0.0 pyyaml-6.0.1 sentry-sdk-2.30.0 setproctitle-1.3.3 smmap-5.0.2 sqlalchemy-2.0.41 typing-extensions-4.7.1 wandb-0.18.7 zipp-3.15.0
# Collecting PyYAML==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Installing collected packages: PyYAML
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
# Successfully installed PyYAML-5.4.1
# Could not find conda environment: cell-tracking-challenge
# You can list all discoverable environments with `conda info --envs`.
#
# ERROR: sentry-sdk 2.30.0 has requirement urllib3>=1.26.11, but you'll have urllib3 1.25.8 which is incompatible.

# %%
# !pip install python-dotenv
import dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %% [markdown]
# # **Training**
#  The first two stages can be skipped (step #2 is long in colab) by using the pre-trained model (in step #3) provided under the [releases](https://github.com/talbenha/cell-tracker-gnn/releases) of the repository. For example for the pretrained model for PhC-C2DH-U373 dataset, download the software and find the model under `software/parameters/Features_Models/PhC-C2DH-U373/all_params.pth`

# %% [markdown]
# # 1. Run feature extraction for metric learning

# %%
##%%bash
#source activate cell-tracking-challenge
#export HYDRA_FULL_ERROR=1
#export FOLDER_PATH=/content/drive/MyDrive/CellTracking/nature_method_ctc # TODO: update this path
#export DATA_NAME=PhC-C2DH-U373 # TODO: update this path

#python run_feat_extract.py params.input_images="${FOLDER_PATH}/${DATA_NAME}" params.input_masks="${FOLDER_PATH}/${DATA_NAME}" params.input_seg="${FOLDER_PATH}/${DATA_NAME}" params.output_csv="${FOLDER_PATH}/basic_features" params.sequences=['01','02']  params.seg_dir='_GT/TRA' params.basic=True

# %% [markdown]
# # 2. Run metric learning training
#  Pay attention that this cell takes long time on google colab, so you can skip this stage and use the pre-trained model provided under the [releases](https://github.com/talbenha/cell-tracker-gnn/releases) of the repository. For example for the pretrained model for PhC-C2DH-U373 dataset, download the software and find the model under `software/parameters/Features_Models/PhC-C2DH-U373/all_params.pth`

# %%
##%%bash
#source activate cell-tracking-challenge
#export HYDRA_FULL_ERROR=1
#export FOLDER_PATH=/content/drive/MyDrive/CellTracking/nature_method_ctc # TODO: update this path
#export DATA_NAME=PhC-C2DH-U373 # TODO: update this path

#python run_train_metric_learning.py dataset.kwargs.data_dir_img="${FOLDER_PATH}/${DATA_NAME}" dataset.kwargs.data_dir_mask="${FOLDER_PATH}/${DATA_NAME}" dataset.kwargs.dir_csv="${FOLDER_PATH}/basic_features/${DATA_NAME}" dataset.kwargs.subdir_mask='GT/TRA'

# %% [markdown]
# --> output 'all_params.pth' is generated at end, it is the input_model (i.e. for METRIC_PATH variable) for the next step

# %% [markdown]
# # **3. Run compreensive feature extraction with metric learning**

# %% [markdown]
# !pip install python-dotenv
# import dotenv

# %%
# !pip install python-dotenv
import dotenv
# Out:
# Requirement already satisfied: python-dotenv in /home/clark/miniconda3/envs/ctc-tra-linux310/lib/python3.8/site-packages (1.0.1)

# %%
# %%bash
# #source activate cell-tracking-challenge
# #conda activate 99-cell-tra-win11-310
# #source activate ctc-tra-linux310
# export HYDRA_FULL_ERROR=1
# #export FOLDER_PATH=/content/drive/MyDrive/CellTracking/nature_method_ctc
# export FOLDER_PATH=/home/clark/data/gnntest
# #export METRIC_PATH=/content/drive/MyDrive/CellTracking/nature_method_ctc/software/parameters/Features_Models/PhC-C2DH-U373/all_params.pth # TODO: update this path
# export METRIC_PATH=/home/clark/data/gnntest/software/parameters/Features_Models/PhC-C2DH-U373/all_params.pth # TODO: update this path
#
# export DATA_NAME=PhC-C2DH-U373 # TODO: update this path
#
# python run_feat_extract.py params.input_images="${FOLDER_PATH}/${DATA_NAME}" params.input_masks="${FOLDER_PATH}/${DATA_NAME}" params.input_seg="${FOLDER_PATH}/${DATA_NAME}" params.output_csv="${FOLDER_PATH}/ct_features/" params.sequences=['01','02']  params.seg_dir='_GT/TRA' params.basic=False params.input_model="${METRIC_PATH}"
# Out:
# [2025-06-23 12:03:46,743][numexpr.utils][INFO] - Note: NumExpr detected 48 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# [2025-06-23 12:03:46,743][numexpr.utils][INFO] - NumExpr defaulting to 8 threads.
# Using resnet18 model architecture.
# files were saved to : /home/clark/data/gnntest/ct_features/PhC-C2DH-U373/01/csv
# Using resnet18 model architecture.
# files were saved to : /home/clark/data/gnntest/ct_features/PhC-C2DH-U373/02/csv

# %% [markdown]
# # 4. Run Cell Tracking training

# %%
# %%bash
# #source activate cell-tracking-challenge
# #conda activate 99-cell-tra-win11-310
#
# export HYDRA_FULL_ERROR=1
# #export FOLDER_PATH=/content/drive/MyDrive/CellTracking/nature_method_ctc # TODO: update this path
# export FOLDER_PATH=/home/clark/data/gnntest
#
# export DATA_NAME=PhC-C2DH-U373 # TODO: update this path
# # cell tracking training run
# python run.py datamodule.dataset_params.main_path="${FOLDER_PATH}/ct_features/${DATA_NAME}" datamodule.dataset_params.exp_name="2D_SIM" datamodule.dataset_params.drop_feat=[]
# Out:
# [2025-06-23 17:13:53,067][src.utils.utils][INFO] - Disabling python warnings! <config.disable_warnings=True>
# ⚙ CONFIG
# ├── trainer
# │   └── _target_: pytorch_lightning.Trainer
# │       gpus: 1
# │       min_epochs: 1
# │       max_epochs: 500
# │       weights_summary: top
# │       progress_bar_refresh_rate: 100
# │       terminate_on_nan: true
# │
# ├── model
# │   └── _target_: src.models.celltrack_plmodel.CellTrackLitModel
# │       one_hot_label: true
# │       loss_weights: 65
# │       sample: false
# │       weight_loss: true
# │       directed: true
# │       separate_models: true
# │       optim_module:
# │         target: Adam
# │         kwargs:
# │           lr: 0.001
# │           weight_decay: 1.0e-05
# │       lr_sch_module:
# │         target: null
# │         monitor: val/acc
# │         kwargs:
# │           verbose: true
# │           mode: min
# │       model_params:
# │         target: CellTrack_Model
# │         kwargs:
# │           hand_NodeEncoder_dic:
# │             input_dim: 13
# │             fc_dims:
# │             - 64
# │             - 16
# │           learned_NodeEncoder_dic:
# │             input_dim: 128
# │             fc_dims:
# │             - 64
# │             - 16
# │           intialize_EdgeEncoder_dic:
# │             input_dim: 239
# │             fc_dims:
# │             - 128
# │             - 64
# │           message_passing:
# │             target: CellTrack_GNN
# │             kwargs:
# │               in_channels: 32
# │               hidden_channels: 32
# │               in_edge_channels: 64
# │               hidden_edge_channels_conv: 16
# │               hidden_edge_channels_linear:
# │               - 128
# │               - 64
# │               dropout: 0.0
# │               num_layers: 6
# │               num_nodes_features: 3
# │           edge_classifier_dic:
# │             input_dim: 64
# │             fc_dims:
# │             - 128
# │             - 32
# │             - 1
# │             dropout_p: 0.2
# │             use_batchnorm: false
# │
# ├── datamodule
# │   └── _target_: src.datamodules.celltrack_datamodule_mulSeq.CellTrackDataModul
# │       data_dir: /home/clark/code/99-cell-tracker-gnn-test/data/
# │       batch_size: 8
# │       num_workers: 0
# │       pin_memory: false
# │       train_val_test_split:
# │       - 80
# │       - 20
# │       - 0
# │       sampler_type: from_both
# │       dataset_params:
# │         num_frames: 10
# │         type_file: csv
# │         produce_gt: simple
# │         main_path: /home/clark/data/gnntest/ct_features/PhC-C2DH-U373
# │         dirs_path:
# │           train:
# │           - '01'
# │           - '02'
# │         one_hot_label: true
# │         exp_name: 2D_SIM
# │         overlap: 1
# │         jump_frames: 1
# │         mul_vals:
# │         - 2
# │         - 2
# │         - 2
# │         filter_edges: true
# │         directed: true
# │         edge_feat_embed_dict:
# │           p: 1
# │           use_normalized_x: true
# │           normalized_features: false
# │         separate_models: true
# │         normalize_all_cols: false
# │         same_frame: false
# │         next_frame: true
# │         self_loop: true
# │         normalize: true
# │         debug_visualization: false
# │         which_preprocess: MinMax
# │         drop_feat: []
# │
# ├── callbacks
# │   └── model_checkpoint:
# │         _target_: pytorch_lightning.callbacks.ModelCheckpoint
# │         monitor: val/acc
# │         save_top_k: 1
# │         save_last: true
# │         mode: max
# │         verbose: false
# │         dirpath: checkpoints/
# │         filename: '{epoch:02d}'
# │       early_stopping:
# │         _target_: pytorch_lightning.callbacks.EarlyStopping
# │         monitor: val/acc
# │         patience: 50
# │         mode: max
# │         min_delta: 0
# │
# ├── logger
# │   └── tensorboard:
# │         _target_: pytorch_lightning.loggers.tensorboard.TensorBoardLogger
# │         save_dir: tensorboard/
# │         name: default
# │       csv:
# │         _target_: pytorch_lightning.loggers.csv_logs.CSVLogger
# │         save_dir: .
# │         name: csv/
# │
# └── seed
#     └── None
# [2025-06-23 17:13:53,091][src.train][INFO] - Instantiating datamodule <src.datamodules.celltrack_datamodule_mulSeq.CellTrackDataModule>
# [2025-06-23 17:13:53,123][numexpr.utils][INFO] - Note: NumExpr detected 48 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# [2025-06-23 17:13:53,123][numexpr.utils][INFO] - NumExpr defaulting to 8 threads.
# seq len : [106, 106]
# [2025-06-23 17:13:53,387][src.train][INFO] - Instantiating model <src.models.celltrack_plmodel.CellTrackLitModel>
# [2025-06-23 17:13:53,574][src.train][INFO] - Instantiating callback <pytorch_lightning.callbacks.ModelCheckpoint>
# [2025-06-23 17:13:53,575][src.train][INFO] - Instantiating callback <pytorch_lightning.callbacks.EarlyStopping>
# [2025-06-23 17:13:53,575][src.train][INFO] - Instantiating logger <pytorch_lightning.loggers.tensorboard.TensorBoardLogger>
# [2025-06-23 17:13:53,576][src.train][INFO] - Instantiating logger <pytorch_lightning.loggers.csv_logs.CSVLogger>
# [2025-06-23 17:13:53,576][src.train][INFO] - Instantiating trainer <pytorch_lightning.Trainer>
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# [2025-06-23 17:13:53,578][src.train][INFO] - Logging hyperparameters!
# [2025-06-23 17:13:54,323][src.train][INFO] - Starting training!
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name            | Type                  | Params
# -----------------------------------------------------------
# 0  | model           | CellTrack_Model       | 249 K
# 1  | criterion       | BCEWithLogitsLoss     | 0
# 2  | trClassMetric   | ClassificationMetrics | 0
# 3  | valClassMetric  | ClassificationMetrics | 0
# 4  | testClassMetric | ClassificationMetrics | 0
# 5  | train_PredCount | Countspecific         | 0
# 6  | val_PredCount   | Countspecific         | 0
# 7  | test_PredCount  | Countspecific         | 0
# 8  | train_TarCount  | Countspecific         | 0
# 9  | val_TarCount    | Countspecific         | 0
# 10 | test_TarCount   | Countspecific         | 0
# -----------------------------------------------------------
# 249 K     Trainable params
# 0         Non-trainable params
# 249 K     Total params
# 0.997     Total estimated model params size (MB)
# sample using from_both
# Training dataset length: 170
# Validation dataset length: 42
# Test dataset length: 0
# Saved data_train.csv
# Saved data_val.csv
# Epoch 0: 100%|██████████| 28/28 [00:01<00:00, 15.90it/s]
# Validating: 0it [00:00, ?it/s]
# Epoch 0: 100%|██████████| 28/28 [00:01<00:00, 14.91it/s, loss=0.183, v_num=0_0]
# Epoch 1: 100%|██████████| 28/28 [00:01<00:00, 15.62it/s, loss=0.183, v_num=0_0]
# Validating: 0it [00:00, ?it/s]
# Epoch 1: 100%|██████████| 28/28 [00:01<00:00, 14.75it/s, loss=0.18, v_num=0_0, train/loss=0.184, train/acc=0.133, train/preds_sum=0.000, train/targets_sum=442.0]
# Epoch 2: 100%|██████████| 28/28 [00:01<00:00, 17.05it/s, loss=0.18, v_num=0_0, train/loss=0.184, train/acc=0.133, train/preds_sum=0.000, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 2: 100%|██████████| 28/28 [00:01<00:00, 16.01it/s, loss=0.161, v_num=0_0, train/loss=0.181, train/acc=0.155, train/preds_sum=5.640, train/targets_sum=442.0]
# Epoch 3: 100%|██████████| 28/28 [00:01<00:00, 14.83it/s, loss=0.161, v_num=0_0, train/loss=0.181, train/acc=0.155, train/preds_sum=5.640, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 3: 100%|██████████| 28/28 [00:02<00:00, 13.98it/s, loss=0.162, v_num=0_0, train/loss=0.162, train/acc=0.492, train/preds_sum=189.0, train/targets_sum=442.0]
# Epoch 4: 100%|██████████| 28/28 [00:01<00:00, 16.50it/s, loss=0.162, v_num=0_0, train/loss=0.162, train/acc=0.492, train/preds_sum=189.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 4: 100%|██████████| 28/28 [00:01<00:00, 15.53it/s, loss=0.15, v_num=0_0, train/loss=0.156, train/acc=0.497, train/preds_sum=188.0, train/targets_sum=442.0]
# Epoch 5: 100%|██████████| 28/28 [00:01<00:00, 15.98it/s, loss=0.15, v_num=0_0, train/loss=0.156, train/acc=0.497, train/preds_sum=188.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 5: 100%|██████████| 28/28 [00:01<00:00, 15.07it/s, loss=0.139, v_num=0_0, train/loss=0.151, train/acc=0.509, train/preds_sum=192.0, train/targets_sum=442.0]
# Epoch 6: 100%|██████████| 28/28 [00:01<00:00, 16.21it/s, loss=0.139, v_num=0_0, train/loss=0.151, train/acc=0.509, train/preds_sum=192.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 6: 100%|██████████| 28/28 [00:01<00:00, 15.25it/s, loss=0.145, v_num=0_0, train/loss=0.139, train/acc=0.538, train/preds_sum=209.0, train/targets_sum=442.0]
# Epoch 7: 100%|██████████| 28/28 [00:02<00:00, 11.36it/s, loss=0.145, v_num=0_0, train/loss=0.139, train/acc=0.538, train/preds_sum=209.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 7: 100%|██████████| 28/28 [00:02<00:00, 10.85it/s, loss=0.147, v_num=0_0, train/loss=0.146, train/acc=0.522, train/preds_sum=199.0, train/targets_sum=442.0]
# Epoch 8: 100%|██████████| 28/28 [00:01<00:00, 15.62it/s, loss=0.147, v_num=0_0, train/loss=0.146, train/acc=0.522, train/preds_sum=199.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 8: 100%|██████████| 28/28 [00:01<00:00, 14.70it/s, loss=0.143, v_num=0_0, train/loss=0.145, train/acc=0.550, train/preds_sum=214.0, train/targets_sum=442.0]
# Epoch 9: 100%|██████████| 28/28 [00:02<00:00, 14.19it/s, loss=0.143, v_num=0_0, train/loss=0.145, train/acc=0.550, train/preds_sum=214.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 9: 100%|██████████| 28/28 [00:02<00:00, 12.72it/s, loss=0.137, v_num=0_0, train/loss=0.143, train/acc=0.576, train/preds_sum=235.0, train/targets_sum=442.0]
# Epoch 10: 100%|██████████| 28/28 [00:01<00:00, 14.74it/s, loss=0.137, v_num=0_0, train/loss=0.143, train/acc=0.576, train/preds_sum=235.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 10: 100%|██████████| 28/28 [00:02<00:00, 13.87it/s, loss=0.145, v_num=0_0, train/loss=0.141, train/acc=0.545, train/preds_sum=212.0, train/targets_sum=442.0]
# Epoch 11: 100%|██████████| 28/28 [00:01<00:00, 17.40it/s, loss=0.145, v_num=0_0, train/loss=0.141, train/acc=0.545, train/preds_sum=212.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 11: 100%|██████████| 28/28 [00:01<00:00, 16.23it/s, loss=0.147, v_num=0_0, train/loss=0.142, train/acc=0.574, train/preds_sum=228.0, train/targets_sum=442.0]
# Epoch 12: 100%|██████████| 28/28 [00:01<00:00, 17.10it/s, loss=0.147, v_num=0_0, train/loss=0.142, train/acc=0.574, train/preds_sum=228.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 12: 100%|██████████| 28/28 [00:01<00:00, 16.05it/s, loss=0.137, v_num=0_0, train/loss=0.146, train/acc=0.492, train/preds_sum=178.0, train/targets_sum=442.0]
# Epoch 13: 100%|██████████| 28/28 [00:01<00:00, 16.48it/s, loss=0.137, v_num=0_0, train/loss=0.146, train/acc=0.492, train/preds_sum=178.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 13: 100%|██████████| 28/28 [00:01<00:00, 15.48it/s, loss=0.139, v_num=0_0, train/loss=0.134, train/acc=0.577, train/preds_sum=227.0, train/targets_sum=442.0]
# Epoch 14: 100%|██████████| 28/28 [00:01<00:00, 14.97it/s, loss=0.139, v_num=0_0, train/loss=0.134, train/acc=0.577, train/preds_sum=227.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 14: 100%|██████████| 28/28 [00:02<00:00, 14.08it/s, loss=0.129, v_num=0_0, train/loss=0.134, train/acc=0.576, train/preds_sum=226.0, train/targets_sum=442.0]
# Epoch 15: 100%|██████████| 28/28 [00:01<00:00, 16.31it/s, loss=0.129, v_num=0_0, train/loss=0.134, train/acc=0.576, train/preds_sum=226.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 15: 100%|██████████| 28/28 [00:01<00:00, 15.22it/s, loss=0.0692, v_num=0_0, train/loss=0.132, train/acc=0.604, train/preds_sum=242.0, train/targets_sum=442.0]
# Epoch 16: 100%|██████████| 28/28 [00:01<00:00, 16.61it/s, loss=0.0692, v_num=0_0, train/loss=0.132, train/acc=0.604, train/preds_sum=242.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 16: 100%|██████████| 28/28 [00:01<00:00, 15.53it/s, loss=0.039, v_num=0_0, train/loss=0.0749, train/acc=0.867, train/preds_sum=380.0, train/targets_sum=442.0]
# Epoch 17: 100%|██████████| 28/28 [00:01<00:00, 16.30it/s, loss=0.039, v_num=0_0, train/loss=0.0749, train/acc=0.867, train/preds_sum=380.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 17: 100%|██████████| 28/28 [00:01<00:00, 15.26it/s, loss=0.0259, v_num=0_0, train/loss=0.0407, train/acc=0.942, train/preds_sum=415.0, train/targets_sum=442.0]
# Epoch 18: 100%|██████████| 28/28 [00:02<00:00, 14.34it/s, loss=0.0259, v_num=0_0, train/loss=0.0407, train/acc=0.942, train/preds_sum=415.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 18: 100%|██████████| 28/28 [00:02<00:00, 12.86it/s, loss=0.0183, v_num=0_0, train/loss=0.0256, train/acc=0.975, train/preds_sum=433.0, train/targets_sum=442.0]
# Epoch 19: 100%|██████████| 28/28 [00:01<00:00, 15.78it/s, loss=0.0183, v_num=0_0, train/loss=0.0256, train/acc=0.975, train/preds_sum=433.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 19: 100%|██████████| 28/28 [00:01<00:00, 14.84it/s, loss=0.0127, v_num=0_0, train/loss=0.0184, train/acc=0.978, train/preds_sum=433.0, train/targets_sum=442.0]
# Epoch 20: 100%|██████████| 28/28 [00:01<00:00, 15.46it/s, loss=0.0127, v_num=0_0, train/loss=0.0184, train/acc=0.978, train/preds_sum=433.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 20: 100%|██████████| 28/28 [00:02<00:00, 14.26it/s, loss=0.0106, v_num=0_0, train/loss=0.0129, train/acc=0.981, train/preds_sum=433.0, train/targets_sum=442.0]
# Epoch 21: 100%|██████████| 28/28 [00:01<00:00, 15.95it/s, loss=0.0106, v_num=0_0, train/loss=0.0129, train/acc=0.981, train/preds_sum=433.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 21: 100%|██████████| 28/28 [00:01<00:00, 15.00it/s, loss=0.00966, v_num=0_0, train/loss=0.0101, train/acc=0.984, train/preds_sum=434.0, train/targets_sum=442.0]
# Epoch 22: 100%|██████████| 28/28 [00:02<00:00, 11.41it/s, loss=0.00966, v_num=0_0, train/loss=0.0101, train/acc=0.984, train/preds_sum=434.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 22: 100%|██████████| 28/28 [00:02<00:00, 10.89it/s, loss=0.00806, v_num=0_0, train/loss=0.00949, train/acc=0.986, train/preds_sum=436.0, train/targets_sum=442.0]
# Epoch 23: 100%|██████████| 28/28 [00:01<00:00, 16.01it/s, loss=0.00806, v_num=0_0, train/loss=0.00949, train/acc=0.986, train/preds_sum=436.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 23: 100%|██████████| 28/28 [00:01<00:00, 14.87it/s, loss=0.00567, v_num=0_0, train/loss=0.00762, train/acc=0.989, train/preds_sum=437.0, train/targets_sum=442.0]
# Epoch 24: 100%|██████████| 28/28 [00:01<00:00, 16.43it/s, loss=0.00567, v_num=0_0, train/loss=0.00762, train/acc=0.989, train/preds_sum=437.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 24: 100%|██████████| 28/28 [00:01<00:00, 15.43it/s, loss=0.00582, v_num=0_0, train/loss=0.00563, train/acc=0.991, train/preds_sum=438.0, train/targets_sum=442.0]
# Epoch 25: 100%|██████████| 28/28 [00:01<00:00, 16.32it/s, loss=0.00582, v_num=0_0, train/loss=0.00563, train/acc=0.991, train/preds_sum=438.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch
train/acc=0.999, train/preds_sum=442.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 101: 100%|██████████| 28/28 [00:01<00:00, 14.85it/s, loss=0.000642, v_num=0_0, train/loss=0.00104, train/acc=0.999, train/preds_sum=442.0, train/targets_sum=442.0]
# Epoch 102: 100%|██████████| 28/28 [00:01<00:00, 16.53it/s, loss=0.000642, v_num=0_0, train/loss=0.00104, train/acc=0.999, train/preds_sum=442.0, train/targets_sum=442.0]
# Validating: 0it [00:00, ?it/s]
# Epoch 102: 100%|██████████| 28/28 [00:01<00:00, 15.34it/s, loss=0.000599, v_num=0_0, train/loss=0.000641, train/acc=0.999, train/preds_sum=442.0, train/targets_sum=442.0]
# Epoch 102: 100%|██████████| 28/28 [00:01<00:00, 14.72it/s, loss=0.000599, v_num=0_0, train/loss=0.000641, train/acc=0.999, train/preds_sum=442.0, train/targets_sum=442.0]
# [2025-06-23 17:17:32,719][src.train][INFO] - Starting testing!
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# sample using from_both
# Training dataset length: 170
# Validation dataset length: 42
# Test dataset length: 0
# Saved data_train.csv
# Saved data_val.csv
# Testing: 100%|██████████| 6/6 [00:00<00:00, 57.46it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test/FN_epoch': 0.0,
#  'test/FP_epoch': 0.0,
#  'test/TN_epoch': 449.0,
#  'test/TP_epoch': 2352.0,
#  'test/acc': 1.0,
#  'test/acc_epoch': 1.0,
#  'test/loss': 0.0004052476433571428,
#  'test/prec': 1.0,
#  'test/prec_epoch': 1.0,
#  'test/preds_sum': 392.0,
#  'test/preds_sum_epoch': 2352.0,
#  'test/rec': 1.0,
#  'test/rec_epoch': 1.0,
#  'test/targets_sum': 392.0,
#  'test/targets_sum_epoch': 2352.0}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████| 6/6 [00:00<00:00, 44.84it/s]
# [2025-06-23 17:17:33,629][src.train][INFO] - Finalizing!
# [2025-06-23 17:17:33,629][src.train][INFO] - Best checkpoint path:
# /home/clark/code/99-cell-tracker-gnn-test/logs/runs/2025-06-23/17-13-53/checkpoints/epoch=52.ckpt

# %% [markdown]
# # **Inference**
# Update the following variables:
#
#
# *   MODEL_PYTORCH_LIGHTNING - according to the output of the previius cell
# *   MODEL_METRIC_LEARNING
# *   FOLDER_PATH - path to folder that contains the dataset
# *   MODALITY

# %%
# %%bash
# #source activate cell-tracking-challenge
# export SEQUENCE=01 # sequence number
#
# #export FOLDER_PATH=/content/drive/MyDrive/CellTracking/nature_method_ctc # TODO: update this path
# export FOLDER_PATH=/home/clark/data/gnntest
#
# #export MODEL_METRIC_LEARNING=/content/drive/MyDrive/CellTracking/nature_method_ctc/software/parameters/Features_Models/PhC-C2DH-U373/all_params.pth # TODO: update this path
# export MODEL_METRIC_LEARNING=/home/clark/data/gnntest/software/parameters/Features_Models/PhC-C2DH-U373/all_params.pth # TODO: update this path
#
# #export MODEL_PYTORCH_LIGHTNING='/content/cell-tracker-gnn/logs/runs/2022-07-16/19-37-07/checkpoints/epoch=37.ckpt'
# export MODEL_PYTORCH_LIGHTNING='/home/clark/code/99-cell-tracker-gnn-test/logs/runs/2025-06-23/12-10-16/checkpoints/epoch=28.ckpt'
#
# export DATA_NAME=PhC-C2DH-U373 # TODO: update this path
# export MODALITY="2D"  # dataset modality
#
# export DATASET="${FOLDER_PATH}/${DATA_NAME}"
# export CODE_TRA=src/inference/
# #export PYTHONPATH=/content/cell-tracker-gnn
# export PYTHONPATH=/home/clark/code/99-cell-tracker-gnn-test
#
# # our model needs CSVs, so let's create from image and segmentation.
# python ${CODE_TRA}/preprocess_seq2graph_clean.py -cs 20 -ii "${DATASET}/${SEQUENCE}" -iseg "${DATASET}/${SEQUENCE}_GT/TRA" -im "${MODEL_METRIC_LEARNING}" -oc "${DATASET}/${SEQUENCE}_CSV"
#
# # run the prediction
# python ${CODE_TRA}/inference_clean.py -mp "${MODEL_PYTORCH_LIGHTNING}" -ns "${SEQUENCE}" -oc "${DATASET}"
#
# # create label maps
# python ${CODE_TRA}/postprocess_clean.py -modality "${MODALITY}" -iseg "${DATASET}/${SEQUENCE}_GT/TRA" -oi "${DATASET}/${SEQUENCE}_RES_inference"
# Out:
# number of detected changes: 0
# 0
# global_delta_row: 46
# global_delta_col: 37
# We don't assign new region of interest - use the old one
# Using resnet18 model architecture.
# files were saved to : /home/clark/data/gnntest/PhC-C2DH-U373/01_CSV/csv
# load model from: /home/clark/code/99-cell-tracker-gnn-test/logs/runs/2025-06-23/12-10-16/checkpoints/epoch=28.ckpt
# "directed":        True
# "loss_weights":    65
# "lr":              0.001
# "lr_sch_module":   {'target': None, 'monitor': 'val/acc', 'kwargs': {'verbose': True, 'mode': 'min'}}
# "model_params":    {'target': 'CellTrack_Model', 'kwargs': {'hand_NodeEncoder_dic': {'input_dim': 13, 'fc_dims': [64, 16]}, 'learned_NodeEncoder_dic': {'input_dim': 128, 'fc_dims': [64, 16]}, 'intialize_EdgeEncoder_dic': {'input_dim': 239, 'fc_dims': [128, 64]}, 'message_passing': {'target': 'CellTrack_GNN', 'kwargs': {'in_channels': 32, 'hidden_channels': 32, 'in_edge_channels': 64, 'hidden_edge_channels_conv': 16, 'hidden_edge_channels_linear': [128, 64], 'dropout': 0.0, 'num_layers': 6, 'num_nodes_features': 3}}, 'edge_classifier_dic': {'input_dim': 64, 'fc_dims': [128, 32, 1], 'dropout_p': 0.2, 'use_batchnorm': False}}}
# "one_hot_label":   True
# "optim_module":    {'target': 'Adam', 'kwargs': {'lr': 0.001, 'weight_decay': 1e-05}}
# "sample":          False
# "separate_models": True
# "weight_decay":    0.0005
# "weight_loss":     True
# Start with /home/clark/data/gnntest/PhC-C2DH-U373/01_CSV/csv
# features: Index(['frame_num', 'area', 'min_row_bb', 'min_col_bb', 'max_row_bb',
#        'max_col_bb', 'centroid_row', 'centroid_col', 'major_axis_length',
#        'minor_axis_length',
#        ...
#        'feat_118', 'feat_119', 'feat_120', 'feat_121', 'feat_122', 'feat_123',
#        'feat_124', 'feat_125', 'feat_126', 'feat_127'],
#       dtype='object', length=141)
# Finish frame index 0
# Finish process /home/clark/data/gnntest/PhC-C2DH-U373/01_CSV/csv (test)
# save path : /home/clark/data/gnntest/PhC-C2DH-U373/01_RES_inference
# Save inference files:
#  - /home/clark/data/gnntest/PhC-C2DH-U373/01_RES_inference/pytorch_geometric_data.pt
#  - /home/clark/data/gnntest/PhC-C2DH-U373/01_RES_inference/all_data_df.csv
#  - /home/clark/data/gnntest/PhC-C2DH-U373/01_RES_inference/raw_output.pt
# Load /home/clark/data/gnntest/PhC-C2DH-U373/01_RES_inference/pytorch_geometric_data.pt
# Load /home/clark/data/gnntest/PhC-C2DH-U373/01_RES_inference/all_data_df.csv
# Load /home/clark/data/gnntest/PhC-C2DH-U373/01_RES_inference/raw_output.pt
# Number of different vals: 0
